# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashunnam123/VITBML-EDA1/blob/master/TEAM_soul.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**TEAM MEMBERS:**
# * 19PA1A04C4-P.RAM SAI
# * 19PA1A0G3-U.AVINASH
# * 19PA1A04C1-N.ANIL
# * 19PA1A04F6-T.RAVI TEJA

# %% [markdown]
# reading a dataframe of indian elections of year 1996 from the pc [link text](https://www.kaggle.com/kracekumar/indian-elections#1996.csv)

# %%
import pandas as pd
a=pd.read_csv("/content/ram_sai.csv")
print(a)
# Out:
#            %  ... TOTAL POLL PERCENTAGE
# 0      36.82  ...                 65.82
# 1      31.38  ...                 65.82
# 2      29.63  ...                 65.82
# 3       0.99  ...                 65.82
# 4       0.23  ...                 65.82
# ...      ...  ...                   ...
# 13947   0.18  ...                 75.35
# 13948   0.17  ...                 75.35
# 13949   0.17  ...                 75.35
# 13950   0.11  ...                 75.35
# 13951   0.10  ...                 75.35
#
# [13952 rows x 12 columns]

# %% [markdown]
# Drawing a Bar Graph for the Given data of first 10 Rows

# %%
import seaborn as sns
sns.pairplot(data=a)

# %%
import matplotlib.pyplot as plt
#b=a.head(10)
b.plot(kind="bar")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fda3370d0559> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 #b=a.head(10)
# ----> 3 b.plot(kind="bar")
#       4 plt.show()
#
# NameError: name 'b' is not defined

# %% [markdown]
# Deleting the Some of the Rows and Coloums from the Data Set

# %%
import numpy as np
b=a.iloc[0:15,0:4]
b.iloc[0:5,0:4]=np.nan
print(b)

# %% [markdown]
# Removing the '%' coloum from the Data Set

# %%
a.drop(["%"],axis=1,inplace=True)
print(a)

# %% [markdown]
# Setting the coloum which is named as 'CANDIDATE' as Index

# %%
a.set_index("CANDIDATE",inplace=True)
print(a)

# %% [markdown]
# Filling the empty places with the 'srikakulam'

# %%
t=a.fillna("srikakulam")
print(t)

# %% [markdown]
# Slicing the Data Set to [1:6,1:4]

# %%
a.iloc[1:6,1:4]
print(a)

# %%
a=a.rename(columns={"CONSTITUENCY":"AREA"})
print(a)
